# %% [markdown]
# ## Importe de bibliotecas

# %%
import multiprocessing

from gensim.models import Word2Vec

import pandas as pd

# %% [markdown]
# ## Carga de datos

# %%
resumenes_docentes = pd.read_csv("ruta")
resumenes_estudiantes = pd.read_csv("rutagr")

# %% [markdown]
# ## Verificacion datos

# %%
resumenes_docentes.shape
# Out:
# (308, 17)

# %%
resumenes_docentes.head(3)
# Out:
#    index  codigo                                             titulo  \
# 0      1  1464.0  "Diagnóstico del impacto de las iniciativas em...
# 1      2  1367.0  Acoso Escolar (Bullying) en San Juan de Pasto....
# 2      3  1343.0  ACTIVIDAD ANTIBACTERIAL DE POLIFENOLES DEL AGU...
#
#                                              resumen    estado  id_autor  \
# 0  El emprendimiento es entre otras acepciones es...   Vencido   13515.0
# 1  A nivel mundial, uno de cada tres escolares ha...  Prorroga   11902.0
# 2  El cáncer gástrico (CG) es la principal causa ...   Vencido   10081.0
#
#                         nombre_autor    programa  \
# 0             Francisco Rafael Ayala      Diseño
# 1      Harvey Mauricio Herrera Lopez  Psicología
# 2  Nelson Humberto Hurtado Gutierrez     Química
#
#                        facultad  convocatoria  \
# 0                         Artes  Docente 2017
# 1              Ciencias Humanas  Docente 2017
# 2  Ciencias Exactas y Naturales  Docente 2016
#
#                                  grupo_investigacion  \
# 0                            Currículo y Universidad
# 1                                 Psicología y Salud
# 2  GRUPO DE INVESTIGACIÓN EN PRODUCTOS DE IMPORTA...
#
#                            linea_investigacion   palabras_clave  \
# 0                       Curriculos pertinentes      Diagnóstico
# 1  Aspectos Psicosociales en Procesos de Salud    Acoso Escolar
# 2                           Modelado molecular  cancer gastrico
#
#                                               corpus  \
# 0  "Diagnóstico del impacto de las iniciativas em...
# 1  Acoso Escolar (Bullying) en San Juan de Pasto....
# 2  ACTIVIDAD ANTIBACTERIAL DE POLIFENOLES DEL AGU...
#
#                                      palabras_corpus  \
# 0  diagnóstico impacto iniciativas emprendedoras ...
# 1  acoso escolar bullying san juan pasto modelo e...
# 2  actividad antibacterial polifenoles aguacate p...
#
#                                         lemas_corpus  \
# 0   diagnóstico impactar iniciativo emprendedor e...
# 1   acosar escolar bullying santo juan pastar mod...
# 2   actividad antibacterial polifenol aguacate pe...
#
#                                   lemas_corpus_clean
# 0   diagnostico impactar iniciativo emprendedor e...
# 1   acosar escolar bullying santo juan pastar mod...
# 2   actividad antibacterial polifenol aguacate pe...

# %%
resumenes_estudiantes.shape
# Out:
# (143, 19)

# %%
resumenes_estudiantes.head(3)
# Out:
#    index  codigo                                             titulo  \
# 0      1   741.0  AISLAMIENTO, CARACTERIZACION, ESTABILIDAD Y AC...
# 1      2   760.0  ANÁLISIS DE ALGORITMOS PARALELOS PARA LA TAREA...
# 2      3  1412.0  ANÁLISIS DE FUNCIONALIDAD DE LA HERRAMIENTA DE...
#
#                                              resumen     estado  id_autor  \
# 0  El color es una de las cualidades sensoriales ...  Terminado   12324.0
# 1  La propuesta de la investigación se centra en ...  Cancelado   12479.0
# 2  Hoy en día se puede encontrar muchas opciones ...    Vencido   13872.0
#
#                        nombre_autor                programa departamento  \
# 0  Omaira Carolina Betancourt Ramos                 Química      Química
# 1       Rosa Maria Zambrano Burbano  Ingeniería de Sistemas     Sistemas
# 2        Carlos Mario Coral Cabrera  Ingeniería de Sistemas     Sistemas
#
#                        facultad    nombre_asesor  \
# 0  Ciencias Exactas y Naturales  Nelson Humberto
# 1                    Ingeniería   Manuel Ernesto
# 2                    Ingeniería   Silvio Ricardo
#
#                           convocatoria  \
# 0  Adicional de Trabajos de Grado 2013
# 1  Adicional de Trabajos de Grado 2013
# 2                     Estudiantil 2017
#
#                                  grupo_investigacion  \
# 0  GRUPO DE INVESTIGACIÓN EN PRODUCTOS DE IMPORTA...
# 1                                              GRIAS
# 2                                              GRIAS
#
#                                  linea_investigacion  \
# 0                                Productos naturales
# 1  Deteccione de patrones con tecnicas de mineria...
# 2   Descubrimiento de conocimiento en bases de datos
#
#               palabras_clave  \
# 0
# 1
# 2  Análisis de funcionalidad
#
#                                               corpus  \
# 0  AISLAMIENTO, CARACTERIZACION, ESTABILIDAD Y AC...
# 1  ANÁLISIS DE ALGORITMOS PARALELOS PARA LA TAREA...
# 2  ANÁLISIS DE FUNCIONALIDAD DE LA HERRAMIENTA DE...
#
#                                      palabras_corpus  \
# 0  aislamiento caracterizacion estabilidad activi...
# 1  análisis algoritmos paralelos tarea minería da...
# 2  análisis funcionalidad herramienta inteligenci...
#
#                                         lemas_corpus  \
# 0   aislamiento caracterizacion estabilidad activ...
# 1   análisis algoritmo paralelo tarea minería dat...
# 2   análisis funcionalidad herramienta inteligenc...
#
#                                   lemas_corpus_clean
# 0   aislamiento caracterizacion estabilidad activ...
# 1   analisis algoritmo paralelo tarea mineria dat...
# 2   analisis funcionalidad herramienta inteligenc...

# %% [markdown]
# ## Bigramas

# %%
# from gensim.models.phrases import Phrases, Phraser

# %%
# phrases = Phrases(lemas_corpus_docentes_spliteados, min_count=30, progress_per=10000)

# %%
# bigram = Phraser(phrases)

# %%
# sentences = bigram[lemas_corpus_docentes_spliteados]

# %% [markdown]
# ## Preparación de datos

# %% [markdown]
# ### Docentes

# %%
lemas_corpus_docentes=resumenes_docentes['lemas_corpus_clean']

# %%
lemas_corpus_docentes_agrupados = ""
for row in lemas_corpus_docentes:
    lemas_corpus_docentes_agrupados  = lemas_corpus_docentes_agrupados  + row

# %%
lemas_corpus_docentes_spliteados = lemas_corpus_docentes_agrupados .split()

# %%
lemas_corpus_docentes_spliteados
# Out:
# ['diagnostico',
#  'impactar',
#  'iniciativo',
#  'emprendedor',
#  'egresar',
#  'programar',
#  'diseñar',
#  'industrial',
#  'universidad',
#  'nariño',
#  'emprendimiento',
#  'acepcion',
#  'capacidad',
#  'humano',
#  'basico',
#  'solucionar',
#  'afrontar',
#  'situacion',
#  'conveniente',
#  'buscar',
#  'beneficiar',
#  'individual',
#  'colectivo',
#  'proposito',
#  'alcanzar',
#  'beneficio',
#  'crecimiento',
#  'desarrollar',
#  'impacto',
#  'nivel',
#  'local',
#  'sociedad',
#  'asociar',
#  'emprendimiento',
#  'emprendedor',
#  'catalogar',
#  'individuo',
#  'disponer',
#  'cambiar',
#  'innovador',
#  'flexible',
#  'dinamico',
#  'capaz',
#  'asumir',
#  'riesgo',
#  'enfrentar',
#  'incertidumbre',
#  'creativo',
#  'disponer',
#  'equipar',
#  'orientar',
#  'crecimiento',
#  'ejercer',
#  'emprendimiento',
#  'emprendedor',
#  'implicar',
#  'participar',
#  'ecosistema',
#  'emprendedor',
#  'conjuntar',
#  'relacionar',
#  'complejo',
#  'entidad',
#  'personar',
#  'emprendedor',
#  'entorno',
#  'tecnologico',
#  'academico',
#  'social',
#  'politico',
#  'economico',
#  'estimulante',
#  'desarrollar',
#  'iniciativo',
#  'emprendedor',
#  'dinamico',
#  'complejidad',
#  'latente',
#  'necesidad',
#  'estructurar',
#  'fomentar',
#  'promover',
#  'emprendimiento',
#  'actor',
#  'sociedad',
#  'casar',
#  'colombiano',
#  'ley',
#  'fomentar',
#  'cultura',
#  'emprendimiento',
#  'promover',
#  'ministerio',
#  'comerciar',
#  'industriar',
#  'turismo',
#  'describir',
#  'papel',
#  'fomentar',
#  'emprendimiento',
#  'promocion',
#  'alianza',
#  'publico',
#  'privar',
#  'academico',
#  'facilitar',
#  'condicionar',
#  'emprendimiento',
#  'desarrollar',
#  'nivel',
#  'local',
#  'capacidad',
#  'emprendedor',
#  'plantear',
#  'objetivo',
#  'estrategico',
#  'establecer',
#  'principio',
#  'ley',
#  'formacion',
#  'integral',
#  'actor',
#  'sistema',
#  'emprendimiento',
#  'particular',
#  'emprendedor',
#  'fortalecimiento',
#  'proceso',
#  'asociativo',
#  'reconocimiento',
#  'concienciar',
#  'derecho',
#  'responsabilidad',
#  'desarrollar',
#  'personar',
#  'individuo',
#  'integrante',
#  'sociedad',
#  'apoyar',
#  'proceso',
#  'emprendimiento',
#  'sostenible',
#  'contexto',
#  'actor',
#  'primordial',
#  'procesar',
#  'emprendedor',
#  'universidad',
#  'institucion',
#  'formador',
#  'profesional',
#  'proyectar',
#  'indagar',
#  'impacto',
#  'iniciativo',
#  'emprendedor',
#  'generar',
#  'egresar',
#  'programar',
#  'diseñar',
#  'industrial',
#  'universidad',
#  'nariño',
#  'marcar',
#  'modalidad',
#  'gradar',
#  'creacion',
#  'empresa',
#  'pretender',
#  'indagar',
#  'fenomeno',
#  'emprendimiento',
#  'contexto',
#  'academico',
#  'identificar',
#  'formar',
#  'modalidad',
#  'manifiesto',
#  'emprendimiento',
#  'egresar',
#  'condicionar',
#  'actual',
#  'programar',
#  'descubrir',
#  'desarrollo',
#  'cambio',
#  'evolucionar',
#  'iniciativo',
#  'emprendedor',
#  'genesis',
#  'consolidacion',
#  'casar',
#  'extremar',
#  'extincion',
#  'tipificar',
#  'caso',
#  'grupo',
#  'crear',
#  'perfilar',
#  'actor',
#  'procesar',
#  'emprendedor',
#  'investigacion',
#  'vital',
#  'importancia',
#  'programar',
#  'diseñar',
#  'industrial',
#  'permitir',
#  'establecer',
#  'mejorar',
#  'relacionar',
#  'egresar',
#  'escuchar',
#  'aporte',
#  'experiencia',
#  'identificar',
#  'necesidad',
#  'interesar',
#  'expectativa',
#  'proponer',
#  'pretender',
#  'aportar',
#  'mejoramiento',
#  'continuo',
#  'curriculo',
#  'plan',
#  'estudio',
#  'programar',
#  'diseñar',
#  'industrial',
#  'contribuir',
#  'desarrollar',
#  'humanar',
#  'profesional',
#  'laboral',
#  'profesional',
#  'egresar',
#  'diagnostico',
#  'diseñar',
#  'arte',
#  'curriculo',
#  'universidad',
#  'curriculos',
#  'pertinente',
#  'francisco',
#  'rafael',
#  'ayala',
#  'acosar',
#  'escolar',
#  'bullying',
#  'santo',
#  'juan',
#  'pastar',
#  'modelar',
#  'explicativo',
#  'predictivo',
#  'gestion',
#  'social',
#  'emocional',
#  'adolescente',
#  'nivel',
#  'mundial',
#  'escolar',
#  'implicar',
#  'bullying',
#  'representar',
#  'panorama',
#  'preocupante',
#  'riesgo',
#  'salud',
#  'mental',
#  'salud',
#  'publico',
#  'generacion',
#  'futuro',
#  'casar',
#  'colombia',
#  'investigacion',
#  'fenomeno',
#  'venir',
#  'incrementar',
#  'decada',
#  'desarrollandose',
#  'especialmente',
#  'ciudad',
#  'capital',
#  'importante',
#  'pais',
#  'concluyente',
#  'sugerir',
#  'valorar',
#  'prevalencia',
#  'referenciar',
#  'nivel',
#  'mundial',
#  'casar',
#  'pastar',
#  'reconocer',
#  'ausencia',
#  'estudio',
#  'dar',
#  'actual',
#  'fenomeno',
#  'caracteristico',
#  'general',
#  'reciente',
#  'estudio',
#  'reconocer',
#  'dimensionar',
#  'perteneciente',
#  'ambito',
#  'relacionar',
#  'interpersonal',
#  'competencia',
#  'social',
#  'incluir',
#  'ajustar',
#  'normativo',
#  'ajustar',
#  'social',
#  'autoeficacia',
#  'social',
#  'importante',
#  'factor',
#  'proteccion',
#  'riesgo',
#  'victimizacion',
#  'agresion',
#  'estudiar',
#  'conjuntar',
#  'igualmente',
#  'relevante',
#  'meter',
#  'social',
#  'empatia',
#  'determinar',
#  'influenciar',
#  'beneficiar',
#  'programar',
#  'estrategia',
#  'intervencion',
#  'prevencion',
#  'bullying',
#  'region',
#  'sur',
#  'colombiano',
#  'estudiar',
#  'objetivar',
#  'establecer',
#  'modelar',
#  'explicativo',
#  'predictivo',
#  'implicacion',
#  'competencia',
#  'social',
#  'meter',
#  'social',
#  'empatia',
#  'acosar',
#  'escolar',
#  'bullying',
#  'adolescente',
#  'escolarizar',
#  'santo',
#  'juan',
#  'pastar',
#  'colombia',
#  'proyectar',
#  'objetivo',
#  'especifico',
#  'fase',
#  'descriptivo',
#  'determinar',
#  'prevalencia',
#  'bullying',
#  'adolescente',
#  'escolarizar',
#  'ciudad',
#  'santo',
#  'juan',
#  'pastar',
#  'colombia',
#  'caracterizar',
#  'conducta',
#  'bullying',
#  'adolescente',
#  'escolarizar',
#  'ciudad',
#  'pastar',
#  'fase',
#  'empirico',
#  'analitico',
#  'post',
#  'facto',
#  'plantear',
#  'analizar',
#  'influenciar',
#  'relacionar',
#  'competencia',
#  'social',
#  'meter',
#  'social',
#  'empatia',
#  'bullying',
#  'adolescente',
#  'escolarizar',
#  'ciudad',
#  'pastar',
#  'previamente',
#  'comprobar',
#  'propiedad',
#  'psicometrico',
#  'escalar',
#  'empatia',
#  'b',
#  'jolliffe',
#  'farrington',
#  'mostrar',
#  'representativo',
#  'municipio',
#  'pastar',
#  'calcular',
#  'conformar',
#  'adolescente',
#  'escolarizar',
#  'secundario',
#  'educacion',
#  'medio',
#  'realizar',
#  'analisis',
#  'factorial',
#  'confirmatorio',
#  'cfa',
#  'modelo',
#  'ecuacion',
#  'estructural',
#  'sem',
#  'teoria',
#  'respuesta',
#  'item',
#  'tri',
#  'descriptivo',
#  'correlacionales',
#  'resultar',
#  'esperar',
#  'configurar',
#  'modelar',
#  'explicativo',
#  'predictivo',
#  'implicacion',
#  'rolar',
#  'agresion',
#  'victimizacion',
#  'analisis',
#  'influenciar',
#  'variable',
#  'competencia',
#  'social',
#  'meter',
#  'social',
#  'empatia',
#  'esperar',
#  'lograr',
#  'validacion',
#  'escalar',
#  'b',
#  'basic',
#  'empathy',
#  'scale',
#  'usar',
#  'mundo',
#  'poblacion',
#  'colombiano',
#  'resultar',
#  'ofrecer',
#  'prevalencia',
#  'fenomeno',
#  'region',
#  'caracterizacion',
#  'descripcion',
#  'permitir',
#  'obtener',
#  'necesario',
#  'novedoso',
#  'modelo',
#  'teorico',
#  'explicativo',
#  'predictivo',
#  'analisis',
#  'influenciar',
#  'variable',
#  'estudiar',
#  'beneficiar',
#  'comprension',
#  'fenomeno',
#  'configuracion',
#  'programar',
#  'estrategia',
#  'prevencion',
#  'mitigacion',
#  'intervencion',
#  'bullying',
#  'pastar',
#  'ofrecer',
#  'valioso',
#  'evidenciar',
#  'reflexion',
#  'mejoramiento',
#  'politico',
#  'publicar',
#  'regional',
#  'referir',
#  'fenomeno',
#  'acosar',
#  'escolar',
#  'psicologia',
#  'ciencia',
#  'humano',
#  'psicologia',
#  'salud',
#  'aspecto',
#  'psicosocial',
#  'proceso',
#  'salud',
#  'harvey',
#  'mauricio',
#  'herrera',
#  'lopez',
#  'actividad',
#  'antibacterial',
#  'polifenol',
#  'aguacate',
#  'persea',
#  'americano',
#  'var',
#  'hass',
#  'helicobacter',
#  'pylori',
#  'aislar',
#  'paciente',
#  'zona',
#  'alto',
#  'riesgo',
#  'cancer',
#  'gastrico',
#  'departamento',
#  'nariño',
#  'cancer',
#  'gastrico',
#  'principal',
#  'causar',
#  'muerte',
#  'cancer',
#  'colombia',
#  'particularmente',
#  'region',
#  'andino',
#  'nariño',
#  'incidencia',
#  'alto',
#  'mundo',
#  'infeccion',
#  'helicobacter',
#  'pylori',
#  'principal',
#  'factor',
#  'riesgo',
#  'enfermedad',
#  'factor',
#  'dieta',
#  'polimorfismo',
#  'humano',
#  'condicionar',
#  'socio',
#  'cultural',
#  'higienico',
#  'sanitario',
#  'ejercer',
#  'fuerza',
#  'multifactoriales',
#  'incidencia',
#  'mortalidad',
#  'enfermedad',
#  'respuesta',
#  'problema',
#  'infeccion',
#  'pylori',
#  'papel',
#  'preponderante',
#  'desenlazar',
#  'procesar',
#  'precanceroso',
#  'incentivar',
#  'busqueda',
#  'biomoleculas',
#  'activo',
#  'producto',
#  'vegetal',
#  'evaluacion',
#  'accion',
#  'biologico',
#  'extracto',
#  'origen',
#  'natural',
#  'establecer',
#  'alternativo',
#  'interesante',
#  'controlar',
#  'solucion',
#  'actual',
#  'problematico',
#  'acarrear',
#  'medicamento',
#  'sintetico',
#  'tratamiento',
#  'infeccion',
#  'pylori',
#  'polifenol',
#  'aguacate',
#  'americano',
#  'alternativo',
#  'tratamiento',
#  'erradicacion',
#  'infeccion',
#  'propiedad',
#  'antioxidante',
#  'antiinflamatorias',
#  'mucoprotectoras',
#  'inhibitorio',
#  'crecimiento',
#  'microorganismo',
#  'necesario',
#  'aislar',
#  'pylori',
#  'mucoso',
#  'gastrico',
#  'pasar',
#  'inicial',
#  'evaluar',
#  'respuesta',
#  'frente',
#  'compuesto',
#  'origen',
#  'vegetal',
#  'disponible',
#  'region',
#  'nariño',
#  'aguacate',
#  'iniciar',
#  'linear',
#  'estudio',
#  'posterior',
#  'permitir',
#  'generar',
#  'conocimiento',
#  'basar',
#  'propiedad',
#  'biomoleculas',
#  'implementacion',
#  'futuro',
#  'prevenir',
#  'patogenesis',
#  'cancer',
#  'gastrico',
#  'disminuir',
#  'riesgo',
#  'padecimiento',
#  'municipio',
#  'pastar',
#  'alto',
#  'riesgo',
#  'cancer',
#  'gastrico',
#  'quimico',
#  'ciencia',
#  'exacto',
#  'natural',
#  'grupo',
#  'investigacion',
#  'producto',
#  'importancia',
#  'biologico',
#  'gipib',
#  'modelar',
#  'molecular',
#  'nelson',
#  'humberto',
#  'hurtado',
#  'gutierrez',
#  'actividad',
#  'antibacterial',
#  'citotoxico',
#  'vitro',
#  'aceite',
#  'vegetal',
#  'semilla',
#  'fruto',
#  'tropical',
#  'andino',
#  'departamento',
#  'nariño',
#  'gracia',
#  'posicion',
#  'geografico',
#  'presentar',
#  'diversidad',
#  'piso',
#  'termico',
#  'clima',
#  'permitir',
#  'producir',
#  'variedad',
#  'cultivo',
#  'fruto',
#  'utilizar',
#  'elaboracion',
#  'jugo',
#  'mermelada',
#  'dulce',
#  'almibarar',
#  'jalear',
#  'bocadillo',
#  'generar',
#  'considerable',
#  'cantidad',
#  'residuo',
#  'cascar',
#  'semilla',
#  'normalmente',
#  'eliminar',
#  'rellenar',
#  'sanitario',
#  'ocasionar',
#  'utilizar',
#  'abonar',
#  'organico',
#  'grupo',
#  'tecnologia',
#  'emergente',
#  'agroindustria',
#  'tea',
#  'universidad',
#  'nariño',
#  'interesar',
#  'agregar',
#  'residuo',
#  'semilla',
#  'fruto',
#  'cultivar',
#  'nariño',
#  'psidium',
#  'guajava',
#  'guayaba',
#  'solanun',
#  'quitoense',
#  'lulo',
#  'mangifera',
#  'indicar',
#  'mangar',
#  'passiflora',
#  'edulis',
#  'maracuya',
#  'carica',
#  'papaya',
#  'papaya',
#  'solanum',
#  'betaceum',
#  'tomate',
#  'arbol',
#  'extraer',
#  'aceite',
#  'vegetal',
#  'semilla',
#  'identificar',
#  'composicion',
#  'acido',
#  'graso',
#  'saponificable',
#  'insaponificables',
#  'hurtar',
#  'dorar',
#  'hurtar',
#  'benavides',
#  'martinez',
#  'correar',
#  'ceron',
#  'hurtar',
#  'ayala',
#  'ceron',
#  'hurtar',
#  'ayala',
#  'pantoja',
#  'chamorro',
#  'hurtar',
#  'benavides',
#  'martinez',
#  'correar',
#  'pantoja',
#  'chamorro',
#  'hurtar',
#  'benavides',
#  'martinez',
#  'correar',
#  'obtener',
#  'tecnologia',
#  'fluir',
#  'supercritico',
#  'efs',
#  'catalogandose',
#  'amigable',
#  'ambientar',
#  'libre',
#  'residuo',
#  'organico',
#  'ofrecer',
#  'producto',
#  'aplicacion',
#  'industriar',
#  'farmaceutico',
#  'cosmetologica',
#  'industriar',
#  'alimentario',
#  'tratamiento',
#  'enfermedad',
#  'infeccioso',
#  'farmaco',
#  'basar',
#  'plantar',
#  'incrementar',
#  'año',
#  'costo',
#  'ocurrencia',
#  'efecto',
#  'colateral',
#  'menor',
#  'comparacion',
#  'antibiotico',
#  'convencional',
#  'obtener',
#  'microorganismo',
#  'contener',
#  'molecula',
#  'facilmente',
#  'reconocer',
#  'bacteria',
#  'probabilidad',
#  'disminuir',
#  'extracto',
#  'producto',
#  'obtener',
#  'plantar',
#  'shrestha',
#  'shivcharn',
#  'bioprospeccion',
#  'centrar',
#  'busqueda',
#  'compuesto',
#  'actividad',
#  'biologico',
#  'utilizar',
#  'informacion',
#  'etnobotanica',
#  'seleccion',
#  'plantar',
#  'farmacologico',
#  'bermudez',
#  'exponer',
#  'presentar',
#  'proponer',
#  'aunar',
#  'esfuerzo',
#  'interesar',
#  'conocimiento',
#  'integrante',
#  'grupo',
#  'investigacion',
#  'universidad',
#  'nariño',
#  'salud',
#  'publico',
#  'tecnologia',
#  'emergente',
#  'agroindustria',
#  'objetivar',
#  'determinar',
#  'vitro',
#  'antibacteriano',
#  'bacteria',
#  'gram',
#  'negativo',
#  'escherichia',
#  'coli',
#  'pseudomonas',
#  'aeruginosa',
#  'klebsiella',
#  'pneumoniae',
#  'gram',
#  'positivo',
#  'staphylococcus',
#  'aureus',
#  'enterococcus',
#  'faecium',
#  'adicionalmente',
#  'utilizar',
#  'ser',
#  'humano',
#  'valorar',
#  'actividad',
#  'citotoxica',
#  'eritrocito',
#  'leucocito',
#  'humano',
#  'investigacion',
#  'buscar',
#  'contribuir',
#  'identificar',
#  'potencial',
#  'biologico',
#  'antibacterial',
#  'actividad',
#  'citotoxica',
#  'aceite',
#  'vegetal',
#  'obtener',
#  'previamente',
#  'grupo',
#  'tea',
#  'tecnologia',
#  'efs',
#  'conferir',
#  'agregar',
#  'residuo',
#  'vegetal',
#  'utilidad',
#  'actualidad',
#  'aceite',
#  'vegetal',
#  'biologia',
#  'ciencia',
#  'exacto',
#  'natural',
#  'tecnologia',
#  'emergente',
#  'agroindustria',
#  'ingrediente',
#  'natural',
#  'industriar',
#  'alimentario',
#  'cosmetico',
#  'farmaceutico',
#  'orfa',
#  'alexandra',
#  'españa',
#  'jojoa',
#  'aguar',
#  'extravascular',
#  'pulmonar',
#  'predictor',
#  'mortalidad',
#  'desarrollar',
#  'injuriar',
#  'pulmonar',
#  'agudo',
#  'sindrome',
#  'distres',
#  'respiratorio',
#  'agudo',
#  'paciente',
#  'shock',
#  'hospital',
#  'universitario',
#  'departamental',
#  'nariño',
#  'resumir',
#  'chocar',
#  'condicion',
#  'clinico',
#  'amenazar',
#  'vida',
#  'reanimacion',
#  'meter',
#  'temprano',
#  'permitir',
#  'disminucion',
#  'absoluto',
#  'mortalidad',
#  'porcentaje',
#  'importante',
#  'paciente',
#  'chocar',
#  'desarrollar',
#  'injuriar',
#  'pulmonar',
#  'agudo',
#  'sindrome',
#  'distres',
#  'respiratorio',
#  'agudo',
#  'ali',
#  ...]

# %% [markdown]
# ### Estudiantes

# %%
lemas_corpus_estudiantes=resumenes_estudiantes['lemas_corpus_clean']

# %%
lemas_corpus_estudiantes_agrupados = ""
for row in lemas_corpus_estudiantes:
    lemas_corpus_estudiantes_agrupados  = lemas_corpus_estudiantes_agrupados  + row

# %%
lemas_corpus_estudiantes_spliteados = lemas_corpus_estudiantes_agrupados.split()

# %%
lemas_corpus_estudiantes_spliteados
# Out:
# ['aislamiento',
#  'caracterizacion',
#  'estabilidad',
#  'actividad',
#  'antioxidante',
#  'vitro',
#  'pigmento',
#  'tipo',
#  'betalainas',
#  'fruto',
#  'opuntia',
#  'dillenii',
#  'color',
#  'cualidad',
#  'sensorial',
#  'importante',
#  'influir',
#  'hora',
#  'aceptar',
#  'rechazar',
#  'alimento',
#  'añadir',
#  'color',
#  'parecer',
#  'meramente',
#  'cosmetico',
#  'dudar',
#  'color',
#  'importante',
#  'percepcion',
#  'consumidor',
#  'alimento',
#  'frecuentemente',
#  'asociar',
#  'sabor',
#  'especifico',
#  'intensidad',
#  'sabor',
#  'problema',
#  'seguridad',
#  'alimentario',
#  'creciente',
#  'preocupacion',
#  'toxicidad',
#  'intolerancia',
#  'alergia',
#  'trastorno',
#  'conducta',
#  'presentar',
#  'colorante',
#  'sintetico',
#  'usar',
#  'industriar',
#  'alimento',
#  'conllevar',
#  'busqueda',
#  'fuente',
#  'colorante',
#  'efecto',
#  'salud',
#  'humano',
#  'proyectar',
#  'investigacion',
#  'seleccionar',
#  'fruto',
#  'cactus',
#  'genero',
#  'opuntia',
#  'reciente',
#  'investigacion',
#  'realizar',
#  'pais',
#  'mostrar',
#  'fuente',
#  'promisorio',
#  'pigmento',
#  'natural',
#  'ventaja',
#  'claro',
#  'colorante',
#  'natural',
#  'tonalidad',
#  'color',
#  'cambiar',
#  'intervalo',
#  'amplio',
#  'alto',
#  'tintorial',
#  'colorante',
#  'artificial',
#  'pigmento',
#  'atractivo',
#  'tecnologicamente',
#  'colorante',
#  'alimento',
#  'caracteristico',
#  'colorante',
#  'mencionar',
#  'propiedad',
#  'medicinal',
#  'terapeutico',
#  'anticancerigena',
#  'atribuir',
#  'alto',
#  'cantidad',
#  'pigmento',
#  'antioxidante',
#  'poseer',
#  'control',
#  'colesterol',
#  'reduccion',
#  'lipido',
#  'sangrar',
#  'triglicerido',
#  'actividad',
#  'antioxidante',
#  'caracteristico',
#  'importancia',
#  'compuesto',
#  'natural',
#  'elemento',
#  'esencial',
#  'proteger',
#  'oxidacion',
#  'macromolecula',
#  'biologico',
#  'cuerpo',
#  'humanar',
#  'proteccion',
#  'antioxidante',
#  'organismo',
#  'clavar',
#  'control',
#  'enfermedad',
#  'cronico',
#  'relevancia',
#  'medicinar',
#  'preventivo',
#  'adicional',
#  'fruto',
#  'cactus',
#  'opuntia',
#  'dillenni',
#  'atractivo',
#  'color',
#  'rojo',
#  'violeta',
#  'especie',
#  'estudiar',
#  'desconocer',
#  'pigmento',
#  'mayoritario',
#  'comportamiento',
#  'antioxidante',
#  'referenciar',
#  'especie',
#  'desconocimiento',
#  'dicha',
#  'cualidad',
#  'fruto',
#  'aprovechar',
#  'formar',
#  'integral',
#  'aplicacion',
#  'industrial',
#  'problema',
#  'plantear',
#  'potencial',
#  'fruto',
#  'colorante',
#  'alimento',
#  'actividad',
#  'biologico',
#  'actividad',
#  'antioxidante',
#  'vitro',
#  'identificar',
#  'quimicamente',
#  'caracteristico',
#  'tipo',
#  'pigmento',
#  'buscar',
#  'solucion',
#  'problema',
#  'plantear',
#  'requerir',
#  'implementar',
#  'metodologia',
#  'adecuar',
#  'permia',
#  'aislar',
#  'compuesto',
#  'interes',
#  'colorante',
#  'normalmente',
#  'cromatografia',
#  'columna',
#  'utilizar',
#  'fase',
#  'estacionario',
#  'sephadex',
#  'amberlita',
#  'caracterizacion',
#  'pigmento',
#  'usar',
#  'tecnico',
#  'hplc',
#  'rmn',
#  'valorar',
#  'capacidad',
#  'reductor',
#  'radical',
#  'libre',
#  'capacidad',
#  'antioxidante',
#  'implementar',
#  'tecnico',
#  'validar',
#  'literatura',
#  'cientifico',
#  'casar',
#  'metodologia',
#  'teac',
#  'capacidad',
#  'antioxidante',
#  'equivalente',
#  'trolox',
#  'dpph',
#  'diphenyl',
#  'picrylhydrazil',
#  'finalmente',
#  'necesario',
#  'valorar',
#  'estabilidad',
#  'extracto',
#  'aislar',
#  'frente',
#  'factor',
#  'luz',
#  'plantear',
#  'diseñar',
#  'experimental',
#  'involucrar',
#  'variable',
#  'quimico',
#  'quimico',
#  'ciencia',
#  'exacto',
#  'natural',
#  'grupo',
#  'investigacion',
#  'producto',
#  'importancia',
#  'biologico',
#  'gipib',
#  'producto',
#  'natural',
#  'omaira',
#  'carolina',
#  'betancourt',
#  'ramos',
#  'nelson',
#  'humberto',
#  'analisis',
#  'algoritmo',
#  'paralelo',
#  'tarea',
#  'mineria',
#  'dato',
#  'asociacion',
#  'proponer',
#  'investigacion',
#  'centrar',
#  'busqueda',
#  'analizar',
#  'algoritmo',
#  'paralelo',
#  'proponer',
#  'tarea',
#  'mineria',
#  'dato',
#  'determinar',
#  'adecuar',
#  'finalmente',
#  'definir',
#  'algoritmo',
#  'investigacion',
#  'proposito',
#  'adquirir',
#  'conocimiento',
#  'enfasis',
#  'mejorar',
#  'rendimiento',
#  'calculo',
#  'itemsets',
#  'obtener',
#  'resultar',
#  'limite',
#  'aceptable',
#  'incrementar',
#  'numero',
#  'recurso',
#  'tecnologia',
#  'ofrecer',
#  'finalmente',
#  'explorar',
#  'tecnologia',
#  'computo',
#  'informacion',
#  'manejar',
#  'mundo',
#  'obligar',
#  'tecnico',
#  'procesamiento',
#  'basar',
#  'algoritmo',
#  'complejo',
#  'analisis',
#  'complejidad',
#  'relacionar',
#  'eficiencia',
#  'programar',
#  'eficiencia',
#  'medir',
#  'recurso',
#  'computador',
#  'algoritmo',
#  'analisis',
#  'complejidad',
#  'medir',
#  'calculo',
#  'ejecutar',
#  'operacion',
#  'complejidad',
#  'espaciar',
#  'memoria',
#  'contener',
#  'manipular',
#  'programar',
#  'dato',
#  'complejidad',
#  'espaciar',
#  'comparar',
#  'distinto',
#  'algoritmo',
#  'resolver',
#  'problema',
#  'permitir',
#  'rapidez',
#  'eficiencia',
#  'tratamiento',
#  'dato',
#  'analizar',
#  'informacion',
#  'empresa',
#  'vital',
#  'importancia',
#  'tomar',
#  'decision',
#  'casar',
#  'equivocar',
#  'implicar',
#  'costo',
#  'adicional',
#  'perdida',
#  'fracasar',
#  'negociar',
#  'razon',
#  'comun',
#  'herramienta',
#  'informatico',
#  'permitir',
#  'manejar',
#  'volumen',
#  'informacion',
#  'sustraer',
#  'dato',
#  'relevante',
#  'consistir',
#  'seriar',
#  'paso',
#  'permitir',
#  'identificar',
#  'patron',
#  'dato',
#  'procesar',
#  'conocer',
#  'descubrimiento',
#  'conocimiento',
#  'basar',
#  'dato',
#  'dcbd',
#  'mineria',
#  'dato',
#  'etapa',
#  'procesar',
#  'dcbd',
#  'tarea',
#  'algoritmo',
#  'permitir',
#  'descubrir',
#  'patron',
#  'oculto',
#  'util',
#  'tomar',
#  'decision',
#  'volumen',
#  'dato',
#  'proponer',
#  'pretender',
#  'analisis',
#  'algoritmo',
#  'paralelo',
#  'mineria',
#  'dato',
#  'asociacion',
#  'objetivar',
#  'implementar',
#  'posteriormente',
#  'tecnico',
#  'permitir',
#  'reducir',
#  'itemsets',
#  'frecuente',
#  'obtener',
#  'finalmente',
#  'investigacion',
#  'implementar',
#  'algoritmo',
#  'ingenieria',
#  'sistema',
#  'sistema',
#  'ingenieria',
#  'grias',
#  'deteccione',
#  'patron',
#  'tecnicas',
#  'mineria',
#  'dato',
#  'rosa',
#  'maria',
#  'zambrano',
#  'burbano',
#  'manuel',
#  'ernesto',
#  'analisis',
#  'funcionalidad',
#  'herramienta',
#  'inteligencia',
#  'negocio',
#  'software',
#  'librar',
#  'spago',
#  'orientar',
#  'pyme',
#  'region',
#  'encontrar',
#  'opcion',
#  'mejorar',
#  'gestion',
#  'interior',
#  'empresa',
#  'apuesto',
#  'excelente',
#  'manejar',
#  'informacion',
#  'facilitar',
#  'tomar',
#  'decision',
#  'inteligencia',
#  'negocio',
#  'estrategia',
#  'empresarial',
#  'permitir',
#  'optimizar',
#  'utilizacion',
#  'recurso',
#  'monitorear',
#  'cumplimiento',
#  'objetivo',
#  'empresa',
#  'capacidad',
#  'tomar',
#  'decision',
#  'obtener',
#  'mejorar',
#  'resultar',
#  'presentar',
#  'proyectar',
#  'investigacion',
#  'plantear',
#  'manejar',
#  'herramienta',
#  'inteligencia',
#  'negocio',
#  'software',
#  'librar',
#  'spago',
#  'unico',
#  'plataforma',
#  'open',
#  'source',
#  'cubrir',
#  'satisfacer',
#  'requisito',
#  'inteligencia',
#  'negocio',
#  'termino',
#  'analisis',
#  'gestion',
#  'dato',
#  'administracion',
#  'seguridad',
#  'estrategia',
#  'implementar',
#  'herramienta',
#  'inteligencia',
#  'negocio',
#  'software',
#  'librar',
#  'pyme',
#  'region',
#  'permitir',
#  'soportar',
#  'tomar',
#  'decision',
#  'acertar',
#  'emprender',
#  'accionar',
#  'satisfacer',
#  'objetivo',
#  'aumentar',
#  'competitividad',
#  'empresa',
#  'apropiacion',
#  'conocimiento',
#  'relacionar',
#  'inteligencia',
#  'negocio',
#  'manejar',
#  'herramienta',
#  'spago',
#  'aplicar',
#  'analisis',
#  'prueba',
#  'pro',
#  'presentar',
#  'estudiante',
#  'programar',
#  'profesional',
#  'universidad',
#  'nariño',
#  'cuyo',
#  'resultar',
#  'ayudar',
#  'soportar',
#  'decision',
#  'dependencia',
#  'tipo',
#  'administrativo',
#  'academico',
#  'universidad',
#  'proyectar',
#  'desarrollar',
#  'estudiante',
#  'investigador',
#  'grupo',
#  'investigacion',
#  'grias',
#  'programar',
#  'ingenieria',
#  'sistema',
#  'facultar',
#  'ingenieria',
#  'universidad',
#  'nariño',
#  'analisis',
#  'funcionalidad',
#  'ingenieria',
#  'sistema',
#  'sistema',
#  'ingenieria',
#  'grias',
#  'descubrimiento',
#  'conocimiento',
#  'base',
#  'dato',
#  'carlos',
#  'mario',
#  'coral',
#  'cabrera',
#  'silvio',
#  'ricardo',
#  'analisis',
#  'contribucion',
#  'socioeconomico',
#  'mujer',
#  'trabajador',
#  'zona',
#  'rural',
#  'municipio',
#  'guachucal',
#  'departamento',
#  'nariño',
#  'mujer',
#  'frecuencia',
#  'segregar',
#  'presentar',
#  'sobrecargar',
#  'reconocimiento',
#  'social',
#  'merecer',
#  'mujer',
#  'realizar',
#  'multiple',
#  'tarea',
#  'hogar',
#  'remuneracion',
#  'solventar',
#  'necesidad',
#  'depender',
#  'tarea',
#  'realizar',
#  'cuidar',
#  'tarea',
#  'mujer',
#  'realizar',
#  'apoyar',
#  'hombre',
#  'jefe',
#  'hogar',
#  'aportar',
#  'hogar',
#  'sustentar',
#  'realizacion',
#  'tarea',
#  'productivo',
#  'actividad',
#  'hogar',
#  'recibir',
#  'retribucion',
#  'economico',
#  'reproductivo',
#  'productivo',
#  'realizar',
#  'subvalorar',
#  'inequidad',
#  'condicionar',
#  'enfrentar',
#  'hombre',
#  'dificil',
#  'acceso',
#  'medio',
#  'produccion',
#  'talar',
#  'tierra',
#  'aguar',
#  'semilla',
#  'insumo',
#  'recurso',
#  'financiero',
#  'tecnologia',
#  'etcetera',
#  'brecha',
#  'presentar',
#  'participacion',
#  'politico',
#  'autonomia',
#  'economico',
#  'decision',
#  'presentar',
#  'arraigar',
#  'sociocultural',
#  'sistema',
#  'patriarcal',
#  'tradicionalmente',
#  'politico',
#  'gubernamental',
#  'sector',
#  'rural',
#  'dirigir',
#  'prioritariamente',
#  'hacer',
#  'hombre',
#  'unico',
#  'productor',
#  'desconocer',
#  'mujer',
#  'desarrollar',
#  'multiple',
#  'actividad',
#  'relacionar',
#  'sector',
#  'agropecuario',
#  'laborar',
#  'domestico',
#  'dejar',
#  'resultar',
#  'inseguridad',
#  'economico',
#  'bajo',
#  'nivelar',
#  'cobertura',
#  'sistema',
#  'proteccion',
#  'social',
#  'insuficiente',
#  'oportunidad',
#  'mujer',
#  'rural',
#  'desarrollar',
#  'capacidad',
#  'laboral',
#  'educativo',
#  'tecnico',
#  'productivo',
#  'ampliar',
#  'contribucion',
#  'agregar',
#  'sector',
#  'agropecuario',
#  'rural',
#  'territorio',
#  'contexto',
#  'realidad',
#  'mujer',
#  'especial',
#  'vivir',
#  'zona',
#  'rural',
#  'vivir',
#  'enfrentar',
#  'multiple',
#  'obstaculo',
#  'inequidades',
#  'estructural',
#  'permitir',
#  'empoderamiento',
#  'pleno',
#  'desarrollar',
#  'humanar',
#  'economico',
#  'social',
#  'dicha',
#  'desventaja',
#  'papel',
#  'dinamizadoras',
#  'economia',
#  'rural',
#  'cobrar',
#  'importancia',
#  'desarrollar',
#  'integral',
#  'region',
#  'ende',
#  'necesario',
#  'desarrollar',
#  'transformacion',
#  'socio',
#  'productivo',
#  'territorio',
#  'rural',
#  'reflejar',
#  'participacion',
#  'mujer',
#  'escenario',
#  'productivo',
#  'participacion',
#  'campar',
#  'economico',
#  'politico',
#  'social',
#  'cultural',
#  'alcanzar',
#  'desarrollar',
#  'rural',
#  'agricultura',
#  'cerrar',
#  'brecha',
#  'desigualdad',
#  'aspecto',
#  'posesion',
#  'tierra',
#  'acceso',
#  'financiacion',
#  'tecnologia',
#  'etcetera',
#  'manifestar',
#  'resultar',
#  'conllevar',
#  'estrategia',
#  'mejoramiento',
#  'crear',
#  'condicionar',
#  'vida',
#  'bienestar',
#  'mujer',
#  'zona',
#  'rural',
#  'cumplimiento',
#  'objetivo',
#  'plantear',
#  'proponer',
#  'investigacion',
#  'acabar',
#  'metodologia',
#  'estudiar',
#  'desarrollar',
#  'instrumento',
#  'investigacion',
#  'encuestar',
#  'recoleccion',
#  'fuente',
#  'informacion',
#  'primario',
#  'consecuentemente',
#  'generar',
#  'conocimiento',
#  'temer',
#  'estudiar',
#  'nivel',
#  'regional',
#  'necesario',
#  'recurso',
#  'financiero',
#  'utilizar',
#  'gasto',
#  'requerir',
#  'obtencion',
#  'informacion',
#  'primario',
#  'papeleria',
#  'transportar',
#  'indispensable',
#  'obtener',
#  'resultar',
#  'esperar',
#  'investigacion',
#  'contribucion',
#  'economica',
#  'economia',
#  'economia',
#  'ciencia',
#  'economico',
#  'administrativo',
#  'coyuntura',
#  'economico',
#  'social',
#  'c',
#  'desarrollar',
#  'regional',
#  'coyuntura',
#  'economico',
#  'social',
#  'ana',
#  'lucia',
#  'taimal',
#  'aza',
#  'robert',
#  'wilson',
#  'analisis',
#  'emision',
#  'causar',
#  'cambiar',
#  'soler',
#  'forestal',
#  'agricola',
#  'granja',
#  'experimental',
#  'botana',
#  'universidad',
#  'nariño',
#  'soler',
#  'fuertemente',
#  'afectar',
#  'actividad',
#  'antropico',
#  'desarrollar',
#  'año',
#  'relevancia',
#  'soler',
#  'vocacion',
#  'coincidir',
#  'lograr',
#  'ver',
#  'afectar',
#  'propiedad',
#  'natural',
#  'sustrato',
#  'desafortunadamente',
#  'explotacion',
#  'actividad',
#  'agricola',
#  'cambiar',
#  'importar',
#  'tendencia',
#  'alteracion',
#  'problematico',
#  'evidente',
#  'degradacion',
#  'soler',
#  'conllevar',
#  'perder',
#  'disminuir',
#  'capacidad',
#  'capturar',
#  'gei',
#  'soler',
#  'natural',
#  'absorber',
#  'gas',
#  'respiracion',
#  'edafico',
#  'sustrato',
#  'modificar',
#  'fuertemente',
#  'perder',
#  'propiedad',
#  'ocasionar',
#  'emision',
#  'gas',
#  'atmosfera',
#  'estudiar',
#  'proponer',
#  'medir',
#  'cantidad',
#  'gas',
#  'emitir',
#  'suelo',
#  'agricola',
#  'forestal',
#  'vocacion',
#  'proteccion',
#  'metodo',
#  'camara',
#  'fijo',
#  'analisis',
#  'cromatologia',
#  'caracterizacion',
#  'gas',
#  'determinar',
#  'tanto',
#  'afeccion',
#  'cambiar',
#  'emision',
#  'gei',
#  'comparar',
#  'propiedad',
#  'quimico',
#  'fisico',
#  'biologico',
#  'soler',
#  'cambiar',
#  'ingenieria',
#  'ambiental',
#  'recurso',
#  'natural',
#  'sistema',
#  'agroforestal',
#  'ciencia',
#  'agricola',
#  'agroforesteria',
#  'recurso',
#  'natural',
#  'suelo',
#  'aguar',
#  'sandra',
#  'milena',
#  'enrriquez',
#  'delgado',
#  'jesus',
#  'antonio',
#  'analisis',
#  'chillido',
#  'ecolocalizacion',
#  'murcielago',
#  'perteneciente',
#  'subfamilia',
#  'phyllostominae',
#  'myotinae',
#  'reservar',
#  'natural',
#  'rio',
#  'ñambi',
#  'orden',
#  'chiroptera',
#  'presentar',
#  'diversidad',
#  'adaptacion',
#  'morfologico',
#  'fisiologico',
#  'etologico',
#  'ecolocalizacion',
#  'señalar',
#  'acustico',
#  'permitir',
#  'reconocer',
#  'diferenciar',
#  'especie',
#  'emplear',
#  ...]

# %%
len(lemas_corpus_docentes_spliteados)
# Out:
# 60917

# %%
len(lemas_corpus_estudiantes_spliteados)
# Out:
# 24630

# %% [markdown]
# ## Word2vec con docentes

# %%
# Fase de creación de modelo


# modelo = Word2Vec(min_count=2,
#                      window=2,
#                      size=10,
#                      sample=0, 
#                      alpha=0.01, 
#                      min_alpha=0.0, 
#                      negative=100,
#                      workers=8)


# modelo

# %%
# Fase de construcción de vocabulario

# vocabulario = modelo.build_vocab([lemas_corpus_docentes_spliteados], progress_per=10000)
# vocabulario

# %%
# Fase de entrenamiento

# entrenamiento = modelo.train([lemas_corpus_docentes_spliteados], total_examples=modelo.corpus_count, epochs=10, report_delay=1)
# entrenamiento
# Out:
# (100000, 609170)

# %%
# para no volver a entrenar
# w2v_model.init_sims(replace=True)

# %% [markdown]
# ## Word2vec con estudiantes

# %%
# Fase de creación de modelo


# modelo2 = Word2Vec(min_count=2,
#                      window=2,
#                      size=10,
#                      sample=0, 
#                      alpha=0.01, 
#                      min_alpha=0.0, 
#                      negative=100,
#                      workers=8)


# modelo2

# %%
# Fase de construcción de vocabulario

# vocabulario2 = modelo2.build_vocab([lemas_corpus_estudiantes_spliteados], progress_per=10000)
# vocabulario2

# %%
# Fase de entrenamiento

# entrenamiento2 = modelo2.train([lemas_corpus_estudiantes_spliteados], total_examples=modelo2.corpus_count, epochs=10, report_delay=1)
# entrenamiento2
# Out:
# (100000, 246300)

# %%
# para no volver a entrenar
# w2v_model.init_sims(replace=True)

# %% [markdown]
# ## Word2vec completo

# %%
lemas_corpus_spliteados_completo = lemas_corpus_docentes_spliteados+lemas_corpus_estudiantes_spliteados

# %%
len(lemas_corpus_spliteados_completo)
# Out:
# 85547

# %%
type(lemas_corpus_spliteados_completo)
# Out:
# list

# %%
modelo3 = Word2Vec(min_count=5,
                     window=2,
                     size=10,
                     sample=0, 
                     alpha=0.01, 
                     min_alpha=0.0, 
                     negative=100,
                     workers=8,
                     sg=1,                     
                  )


modelo3

# %%
# Fase de construcción de vocabulario

vocabulario3 = modelo3.build_vocab([lemas_corpus_spliteados_completo], progress_per=10000)
vocabulario3

# %%
# Fase de entrenamiento

entrenamiento3 = modelo3.train([lemas_corpus_spliteados_completo], total_examples=modelo3.corpus_count, epochs=10, report_delay=1)
entrenamiento3
# Out:
# (100000, 855470)

# %% [markdown]
# ## Exploración de modelo

# %%
modelo3.wv.most_similar(positive=['analizar'], topn=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-85aab0e833ac> in <module>
# ----> 1 modelo3.wv.most_similar(positive=['motor'], topn=30)
#
# NameError: name 'modelo3' is not defined

# %%
modelo3.wv.similarity('social', "sociedad")
# Out:
# 0.9967017

# %%
modelo3.wv.similarity('conocimiento', "conocer")
# Out:
# 0.99894214

# %%
modelo3.wv.similarity('inteligente', "busqueda")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-8b42538619ef> in <module>
# ----> 1 modelo3.wv.similarity('inteligente', "busqueda", topn=20)
#
# TypeError: similarity() got an unexpected keyword argument 'topn'

# %%
modelo3.wv.similarity('agricultura', "motor")
# Out:
# -0.558902

# %%
modelo3.most_similar(positive=['motor', 'busqueda'], negative=['agricultura'], topn=1)
# Out:
# <ipython-input-119-9c8c495ba6aa>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   modelo3.most_similar(positive=['motor', 'busqueda'], negative=['agricultura'], topn=1)
# [('rojo', 0.7963446378707886)]

# %%
modelo3.wv.doesnt_match(["conocimiento","conocer","social"])
# Out:
# /home/grias/anaconda3/envs/tg/lib/python3.8/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'social'

# %%
modelo3.wv.doesnt_match(["motor","sociedad","social"])
# Out:
# /home/grias/anaconda3/envs/tg/lib/python3.8/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'motor'

# %% [markdown]
# ## Visualizacion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style("darkgrid")

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    counter=0
    for word in model.wv.vocab:
        if counter == 50:
            break
        tokens.append(model[word])
        labels.append(word)
        counter= counter+1
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(modelo3)
# Out:
# <ipython-input-101-6e68307c0209>:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   tokens.append(model[word])
